# %%
name = input()
print(f"Hello, {name}!")
# Out:
#  Aruzhan
# Hello, Aruzhan!

# %%
a = input()
b = input()
print(a, b, sep="***")
# Out:
#  a
#  b
# a***b

# %%
x = input()
if x.isdigit():
    print("int")
else:
    print("str")
# Out:
#  456
# int

# %%
a = int(input())
b = int(input())
print(a // b)
print(a / b)
# Out:
#  7
#  2
# 3
# 3.5

# %%
x = int(input())
y = int(input())
print(x ** y)
# Out:
#  2
#  3
# 8

# %%
x = int(input())
y = int(input())
print(a % y)
# Out:
#  7
#  2
# 1

# %%
x = input()
y = int(input())
print(x * y)
# Out:
#  aru
#  3
# aruaruaru

# %%
a = input()
print(len(a))
# Out:
#  Aru
# 3

# %%
a = input()
print(a.upper())
print(a.lower())
# Out:
#  PP2
# PP2
# pp2

# %%
s = input()
print(s[0], s[-1])
# Out:
#  Hello
# H o

# %%
s = input()
print(s[2:5])
# Out:
#  abcdef
# cde

# %%
s = input()
print(s[::-1])
# Out:
#  hello
# olleh

# %%
s = input()
n = int(input())
print(f"Hello, {s}. You are {n} years old.")
# Out:
#  B
#  3
# Hello, B. You are 3 years old.

# %%
s1 = input()
s2 = input()
print(s2 in s1)
# Out:
#  hello world
#  hello
# True

# %%
s1 = input()
s2 = input()
print(s1 + s2)
# Out:
#  a
#  b
# ab

# %%
s1 = input()
s2 = input()
s1, s2 = s2, s1
print(s1, s2)
# Out:
#  a
#  b
# b a

# %%
a = int(input())
if a % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
#  5
# odd

# %%
s = input()
s1 = input()
s2 = input()
print(s.replace(s1, s2))ar
# Out:
#  aru
#  u
#  a
# ara

# %%
a = int(input())
b = int(input())
if a == b:
    print("equal")
else:
    print(max(a, b))
# Out:
#  4
#  4
# equal
