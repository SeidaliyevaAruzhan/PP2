# %%
n = input()   
counter = 0
for i in n:
    digit = int(i)
    if digit % 2 != 0:
        print("Not valid")
        break
else:
    print("Valid")

# %%
def isUsual(num):
    if num <= 0:
        return False

    while num % 2 == 0:
        num //= 2
    while num % 3 == 0:
        num //= 3
    while num % 5 == 0:
        num //= 5

    return num == 1


n = int(input())

if isUsual(n):
    print("Yes")
else:
    print("No")

# %%
def to_int(word):
    if word == 'ONE':
        return '1'
    elif word == 'TWO':
        return '2'
    elif word == 'THR':
        return '3'
    elif word == 'FOU':
        return '4'
    elif word == 'FIV':
        return '5'
    elif word == 'SIX':
        return '6'
    elif word == 'SEV':
        return '7'
    elif word == 'EIG':
        return '8'
    elif word == 'NIN':
        return '9'
    elif word == 'ZER':
        return '0'
def to_str(word):
    if word == '1':
        return 'ONE'
    elif word == '2':
        return 'TWO'
    elif word == '3':
        return 'THR'
    elif word == '4':
        return 'FOU'
    elif word == '5':
        return 'FIV'
    elif word == '6':
        return 'SIX'
    elif word == '7':
        return 'SEV'
    elif word == '8':
        return 'EIG'
    elif word == '9':
        return 'NIN'
    elif word == '0':
        return 'ZER'
number = input()
operation = ""
for i in "+-*":
    if i in number:
        operation = i
        a, b = number.split(i)
new_a = ""
new_b = ""
for i in range(0, len(a), 3):
    new_a += to_int(a[i:i+3])
for i in range(0, len(b), 3):
    new_b += to_int(a[i:i+3])
res = 0
if operation == "+":
    res = int(new_a) + int(new_b)
elif operation == "-":
    res = int(new_a) - int(new_b)
elif operation == "*":
    res = int(new_a) * int(new_b)
for x in str(res):
    print(to_str(x), end="")

# %%
class StringHandler:
    def __init__(self):
        pass
    def getString(self):
        self.word = input()
    def printSring(self):
        print(self.word.upper())
s1 = StringHandler()
s1.getString()
s1.printString()

# %%
class Shape:
    def area():
        return 0
class Square(Shape):
    def __init__(sel, n):
        self.length = n
    def area(self):
        returnn pow(self.length, 2)
class Triangle(Shape):
    def __init__(self):
        self.a, self.b, self.c = map(int, input().split())
    def area(self):
        p = (self.a + self.b + self.c) / 2
        return pow(p * (p - self.a) * (p - self.b) * (p - self.c), 0.5)

n = int(input())
s1 = Square(n)
print(s1.area())

s2 = Triangle()
print(s2.area)

# %%
import math
class Point:
    def __init__(self, a, b):
        self.x = a
        self.y = b
    def show(self):
        print(f"({self.x}, {self.y})")
    def move(self, new_x, new_y):
        self.x = new_x
        self.y = new_y
    def dist(self, new_x, new_y):
        self.x = new_x
        self.y = new_y
    def dist(self, other_point):
        return math.sqrt(pow(other_point.x - self.x,2) + pow(other_point.y - self.y, 2))

x1, y1 = map(int, input().split())
x2, y2 = map(int, input().split())
x3, y3 = map(int, input().split())
p1 = Point(x1, y1)
p1.show()
p1.move(x2, y2)
p1.show()
p2 = Point(x3, y3)
print(f"{p1.dist(p2):.2f})

# %%
class Account:
    def __init__(self, b):
        self.balance = b
    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient Funds")
        else:
            self.balance -= amount
            print(self.balance)
balance, draw = map(int, input().split())
a1 = Account(balance)
a1.withdraw(draw)
# Out:
#  100 150
# Insufficient Funds

# %%
class Shape:
    def area():
        return 0
class Circle(Shape):
    def __init__(self, r):
        self.radius = r
    def area(self):
        return 3.14159 * pow(self.radius, 2)
r = int(input())
circle = Circle(r)
print(f"{circle.area():.2f}")
# Out:
#  5
# 78.54

# %%
class Person:
    def __init__(self, name):
        self.name = name
class Student(Person):
    def __init__(self, name, gpa):
        super().__init__(name)
        self.gpa = gpa
    def display(self):
        print(f"Student: {self.name}, GPA:{self.gpa}" )
name, gpa = map(str, input().split())
gpa = float(gpa)
student = Student(name, gpa)
student.display()
# Out:
#  Aman 3.5
# Student: Aman, GPA:3.5

# %%
class Pair:
    def __init__(self, a, b):
        self.a = a
        self.b = b
    def add(self, another_Pair):
        return f"{self.a + another_Pair.a}{self.b + another_Pair.b}"
a1, b1, a2, b2 = map(int, input().split())
p1 = Pair(a1, b1)
p2 = Pair(a2, b2)
print("Result:", p1.add(p2))
# Out:
#  1 2 3 4
# Result: 46

# %%
class Employee:
    def __init__(self, name, base_salary):
        self.base_salary = float(base_salary)
    def total_salary(self):
        return self.base_slary
class Manager(Employee):
    def __init__(self, name, base_salary, bonus_percent):
        super().__init__(name, base_salary)
        self.bonus_percent = bonus_percent
    def total_salary(self):
        return self.base_salary * (1+ float(self.bonus_percent) / 100)
class Developer(Employee):
    def __init__(self, name, base_salary, completed_projects):
        super().__init__(name, base_salary)
        self.completed_projects = float(completed_projects) * 500
class Intern(Employee):
    pass
data = input().split()
type = data[0]
name = data[1]
base_zp = data[2]
employee = Employee(name, base_zp)
if type == "Manager":
    employee = Manager(name, base_zp, data[3])
    print(f"Name:{employee.name}, Total: {employee.total_salary():..2f})
elif type == "Developer":
    employee = Developer(name, base_zp, data[3])
    print(f"Name:{employee.name}, Total: {employee.total_salary():..2f})
elif type == "Intern":
    employee = Intern(name, base_zp, data[3])
    print(f"Name:{employee.name}, Total: {employee.total_salary():..2f})

# %%
import math
def isPrime(num):
    if num == 1:
        return False
    for i in range (2, int(math.sqrt(num)) + 1):
        if num % i == 0:
            return False
    return True
isPrime_byLambda = lambda num: num > 1 and all(num % i != 0 for i in range(2, int(math.sqrt(num))+1))
numbers = list(map(int, input().split()))
filteres_numbers = filter(isPrime_byLambda, numbers)
print(*list(filtered_numbers_obj))
if len(filtered_numbers) == 0:
    print("No primes")
else:
    print(*filtered_numbers)
# Out:
#  1 4 6 8

# %%
n = int(input())
arr = list(map(int, input().split()))
q = int(input())

for _ in range(q):
    op = input().split()
    if op[0] == "add":
        x = int(op[1])
        arr = list(map(lambda a: a + x, arr))
    elif op[0] == "multiply":
        x = int(op[1])
        arr = list(map(lambda a: a * x, arr))
    elif op[0] == "power":
        x = int(op[1])
        arr = list(map(lambda a: a ** x, arr))
    elif op[0] == "abs":
        arr = list(map(lambda a: abs(a), arr))

print(*arr)
